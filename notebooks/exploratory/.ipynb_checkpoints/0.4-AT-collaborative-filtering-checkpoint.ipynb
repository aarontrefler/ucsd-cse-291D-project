# %% [markdown]
# # Setup

# %%
# Add src/ folder to path
import sys
src_path = '../../code/' 
sys.path.insert(0, src_path) 

import math
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import seaborn as sns


from factor_scatter_matrix import factor_scatter_matrix
from IPython.display import display, HTML
from plot_confusion_matrix import plot_confusion_matrix
from mf import matrix_factorization
from sklearn.metrics import confusion_matrix

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# Matplotlib global settings
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['axes.labelsize'] = 14

# %%
data_df = pd.read_csv("../../data/raw/speed_dating_data.csv", encoding="ISO-8859-1")
HTML(data_df.head(5).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>iid</th>
#       <th>id</th>
#       <th>gender</th>
#       <th>idg</th>
#       <th>condtn</th>
#       <th>wave</th>
#       <th>round</th>
#       <th>position</th>
#       <th>positin1</th>
#       <th>order</th>
#       <th>partner</th>
#       <th>pid</th>
#       <th>match</th>
#       <th>int_corr</th>
#       <th>samerace</th>
#       <th>age_o</th>
#       <th>race_o</th>
#       <th>pf_o_att</th>
#       <th>pf_o_sin</th>
#       <th>pf_o_int</th>
#       <th>pf_o_fun</th>
#       <th>pf_o_amb</th>
#       <th>pf_o_sha</th>
#       <th>dec_o</th>
#       <th>attr_o</th>
#       <th>sinc_o</th>
#       <th>intel_o</th>
#       <th>fun_o</th>
#       <th>amb_o</th>
#       <th>shar_o</th>
#       <th>like_o</th>
#       <th>prob_o</th>
#       <th>met_o</th>
#       <th>age</th>
#       <th>field</th>
#       <th>field_cd</th>
#       <th>undergra</th>
#       <th>mn_sat</th>
#       <th>tuition</th>
#       <th>race</th>
#       <th>imprace</th>
#       <th>imprelig</th>
#       <th>from</th>
#       <th>zipcode</th>
#       <th>income</th>
#       <th>goal</th>
#       <th>date</th>
#       <th>go_out</th>
#       <th>career</th>
#       <th>career_c</th>
#       <th>sports</th>
#       <th>tvsports</th>
#       <th>exercise</th>
#       <th>dining</th>
#       <th>museums</th>
#       <th>art</th>
#       <th>hiking</th>
#       <th>gaming</th>
#       <th>clubbing</th>
#       <th>reading</th>
#       <th>tv</th>
#       <th>theater</th>
#       <th>movies</th>
#       <th>concerts</th>
#       <th>music</th>
#       <th>shopping</th>
#       <th>yoga</th>
#       <th>exphappy</th>
#       <th>expnum</th>
#       <th>attr1_1</th>
#       <th>sinc1_1</th>
#       <th>intel1_1</th>
#       <th>fun1_1</th>
#       <th>amb1_1</th>
#       <th>shar1_1</th>
#       <th>attr4_1</th>
#       <th>sinc4_1</th>
#       <th>intel4_1</th>
#       <th>fun4_1</th>
#       <th>amb4_1</th>
#       <th>shar4_1</th>
#       <th>attr2_1</th>
#       <th>sinc2_1</th>
#       <th>intel2_1</th>
#       <th>fun2_1</th>
#       <th>amb2_1</th>
#       <th>shar2_1</th>
#       <th>attr3_1</th>
#       <th>sinc3_1</th>
#       <th>fun3_1</th>
#       <th>intel3_1</th>
#       <th>amb3_1</th>
#       <th>attr5_1</th>
#       <th>sinc5_1</th>
#       <th>intel5_1</th>
#       <th>fun5_1</th>
#       <th>amb5_1</th>
#       <th>dec</th>
#       <th>attr</th>
#       <th>sinc</th>
#       <th>intel</th>
#       <th>fun</th>
#       <th>amb</th>
#       <th>shar</th>
#       <th>like</th>
#       <th>prob</th>
#       <th>met</th>
#       <th>match_es</th>
#       <th>attr1_s</th>
#       <th>sinc1_s</th>
#       <th>intel1_s</th>
#       <th>fun1_s</th>
#       <th>amb1_s</th>
#       <th>shar1_s</th>
#       <th>attr3_s</th>
#       <th>sinc3_s</th>
#       <th>intel3_s</th>
#       <th>fun3_s</th>
#       <th>amb3_s</th>
#       <th>satis_2</th>
#       <th>length</th>
#       <th>numdat_2</th>
#       <th>attr7_2</th>
#       <th>sinc7_2</th>
#       <th>intel7_2</th>
#       <th>fun7_2</th>
#       <th>amb7_2</th>
#       <th>shar7_2</th>
#       <th>attr1_2</th>
#       <th>sinc1_2</th>
#       <th>intel1_2</th>
#       <th>fun1_2</th>
#       <th>amb1_2</th>
#       <th>shar1_2</th>
#       <th>attr4_2</th>
#       <th>sinc4_2</th>
#       <th>intel4_2</th>
#       <th>fun4_2</th>
#       <th>amb4_2</th>
#       <th>shar4_2</th>
#       <th>attr2_2</th>
#       <th>sinc2_2</th>
#       <th>intel2_2</th>
#       <th>fun2_2</th>
#       <th>amb2_2</th>
#       <th>shar2_2</th>
#       <th>attr3_2</th>
#       <th>sinc3_2</th>
#       <th>intel3_2</th>
#       <th>fun3_2</th>
#       <th>amb3_2</th>
#       <th>attr5_2</th>
#       <th>sinc5_2</th>
#       <th>intel5_2</th>
#       <th>fun5_2</th>
#       <th>amb5_2</th>
#       <th>you_call</th>
#       <th>them_cal</th>
#       <th>date_3</th>
#       <th>numdat_3</th>
#       <th>num_in_3</th>
#       <th>attr1_3</th>
#       <th>sinc1_3</th>
#       <th>intel1_3</th>
#       <th>fun1_3</th>
#       <th>amb1_3</th>
#       <th>shar1_3</th>
#       <th>attr7_3</th>
#       <th>sinc7_3</th>
#       <th>intel7_3</th>
#       <th>fun7_3</th>
#       <th>amb7_3</th>
#       <th>shar7_3</th>
#       <th>attr4_3</th>
#       <th>sinc4_3</th>
#       <th>intel4_3</th>
#       <th>fun4_3</th>
#       <th>amb4_3</th>
#       <th>shar4_3</th>
#       <th>attr2_3</th>
#       <th>sinc2_3</th>
#       <th>intel2_3</th>
#       <th>fun2_3</th>
#       <th>amb2_3</th>
#       <th>shar2_3</th>
#       <th>attr3_3</th>
#       <th>sinc3_3</th>
#       <th>intel3_3</th>
#       <th>fun3_3</th>
#       <th>amb3_3</th>
#       <th>attr5_3</th>
#       <th>sinc5_3</th>
#       <th>intel5_3</th>
#       <th>fun5_3</th>
#       <th>amb5_3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1.0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>10</td>
#       <td>7</td>
#       <td>NaN</td>
#       <td>4</td>
#       <td>1</td>
#       <td>11.0</td>
#       <td>0</td>
#       <td>0.14</td>
#       <td>0</td>
#       <td>27.0</td>
#       <td>2.0</td>
#       <td>35.0</td>
#       <td>20.0</td>
#       <td>20.0</td>
#       <td>20.0</td>
#       <td>0.0</td>
#       <td>5.0</td>
#       <td>0</td>
#       <td>6.0</td>
#       <td>8.0</td>
#       <td>8.0</td>
#       <td>8.0</td>
#       <td>8.0</td>
#       <td>6.0</td>
#       <td>7.0</td>
#       <td>4.0</td>
#       <td>2.0</td>
#       <td>21.0</td>
#       <td>Law</td>
#       <td>1.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4.0</td>
#       <td>2.0</td>
#       <td>4.0</td>
#       <td>Chicago</td>
#       <td>60,521</td>
#       <td>69,487.00</td>
#       <td>2.0</td>
#       <td>7.0</td>
#       <td>1.0</td>
#       <td>lawyer</td>
#       <td>NaN</td>
#       <td>9.0</td>
#       <td>2.0</td>
#       <td>8.0</td>
#       <td>9.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>5.0</td>
#       <td>1.0</td>
#       <td>5.0</td>
#       <td>6.0</td>
#       <td>9.0</td>
#       <td>1.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>9.0</td>
#       <td>8.0</td>
#       <td>1.0</td>
#       <td>3.0</td>
#       <td>2.0</td>
#       <td>15.0</td>
#       <td>20.0</td>
#       <td>20.0</td>
#       <td>15.0</td>
#       <td>15.0</td>
#       <td>15.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>35.0</td>
#       <td>20.0</td>
#       <td>15.0</td>
#       <td>20.0</td>
#       <td>5.0</td>
#       <td>5.0</td>
#       <td>6.0</td>
#       <td>8.0</td>
#       <td>8.0</td>
#       <td>8.0</td>
#       <td>7.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>6.0</td>
#       <td>9.0</td>
#       <td>7.0</td>
#       <td>7.0</td>
#       <td>6.0</td>
#       <td>5.0</td>
#       <td>7.0</td>
#       <td>6.0</td>
#       <td>2.0</td>
#       <td>4.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>6.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>19.44</td>
#       <td>16.67</td>
#       <td>13.89</td>
#       <td>22.22</td>
#       <td>11.11</td>
#       <td>16.67</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>6.0</td>
#       <td>7.0</td>
#       <td>8.0</td>
#       <td>7.0</td>
#       <td>6.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>15.0</td>
#       <td>20.0</td>
#       <td>20.0</td>
#       <td>15.0</td>
#       <td>15.0</td>
#       <td>15.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>

# %% [markdown]
# # Adjacency Matrix

# %%
df = data_df[['iid', 'pid', 'dec', 'gender']]

# remove rows where pid = NaN
df = df[~np.isnan(df['pid'])]

# %%
df.describe()
# Out:
#                iid          pid          dec      gender
# count  8368.000000  8368.000000  8368.000000  8368.00000
# mean    283.863767   283.863767     0.420053     0.50000
# std     158.584899   158.584899     0.493597     0.50003
# min       1.000000     1.000000     0.000000     0.00000
# 25%     154.000000   154.000000     0.000000     0.00000
# 50%     281.000000   281.000000     0.000000     0.50000
# 75%     408.000000   408.000000     1.000000     1.00000
# max     552.000000   552.000000     1.000000     1.00000

# %%
df.head(5)
# Out:
#    iid   pid  dec  gender
# 0    1  11.0    1       0
# 1    1  12.0    1       0
# 2    1  13.0    1       0
# 3    1  14.0    1       0
# 4    1  15.0    1       0

# %%
n_ppl = np.max(df['iid'])
n_dates = df.shape[0]

print("Number of People:", n_ppl)
print("Number of Dates :", n_dates)
# Out:
# Number of People: 552
# Number of Dates : 8368

# %%
def create_adj_matrix(df):
    adj = np.zeros((n_ppl, n_ppl))
    adj.fill(np.nan)
    
    for i in range(df.shape[0]):
        iid_idx = int(df.iloc[i,0] - 1)
        pid_idx = int(df.iloc[i,1] - 1)
        dec = df.iloc[i,2]
    
        if dec == 1:
            adj[iid_idx, pid_idx] = 1
        else:
            adj[iid_idx, pid_idx] = 0
        
    return adj

# %%
adj = create_adj_matrix(df)

# %%
plt.figure(figsize=(12,12))
plt.imshow(adj)
plt.title("One-Sided Decision Matrix")
plt.xlabel("pid")
plt.ylabel("iid")
plt.show()

# %% [markdown]
# Male decisions: bottom-left corner of matrix
# Female decisions: top-right corner of matrix

# %% [markdown]
# # Train-Test Split

# %%
#test_size = round(n_dates * .10)
#test_idx = np.random.choice(np.arange(0,n_dates), size=test_size, replace=False)

# %%
test_idx = np.array([ 525, 2642, 4937, 7296, 7058, 3614,  241, 4862, 2761,  105, 6762,
       4825, 2764, 4611,  229, 3200, 4930,  384, 1822, 1505, 2159, 3484,
       5246, 1237, 5964,  929, 7704, 4606, 6928, 5823, 2402, 7502, 8188,
       6221, 4942, 8054, 3261,  277, 5339, 7781, 2248, 5650, 3479, 7903,
       2836,   47, 8230, 5713, 7518, 6159, 6376, 1397, 2408, 6052, 3906,
       1272, 6524, 7124, 2175, 5887, 3286,  745, 2699, 8213, 8124, 3596,
        727, 1230,  858, 6234, 1142, 2485, 8261, 1627,  213, 1416, 2388,
       3606, 3865, 5691, 7627,  292, 4592, 7869, 3481,   29, 8349, 1804,
       4052, 3138, 6330,  809, 4385, 2332,  275,  593, 3593, 1349, 5034,
        407, 4322, 2197, 5118,  881, 4821, 4183, 2702,  958, 1892, 5515,
       1895, 5814, 4250, 5359, 7164, 2156, 7885, 6186, 3690,  434, 6859,
       3352,   31, 4031, 3689, 6562,  199, 6125, 8026, 1170, 5592,  494,
       7432, 5930, 4272, 6357, 2208, 5852, 1829, 6583, 2339,  587, 8085,
       2160, 6459, 1141,  887, 1587,  665, 2610, 1003, 6780, 3103, 3835,
       6641,  389, 4620, 3192, 4583, 2094, 4978, 3329, 2888, 4725, 1109,
       6134, 5530, 7255, 3745, 3359, 2283, 7524, 1528, 8156, 5986, 8001,
       1265, 5659,   53, 1254, 7405,  193, 2066,  718,  868, 5506, 2956,
       6973, 4022, 5370, 2667, 4109, 6495, 3005, 8150,  185, 2059, 5649,
       5325, 2995, 5418, 1898,  280, 6870, 7090, 3285, 2269, 2095, 1015,
       2648, 6292, 1714, 7545, 7091, 4258, 6206, 2405, 1719, 7981, 8041,
       1740, 2205, 6559, 2881, 6884, 2259, 6198, 3424, 2885, 2650,  788,
       7365, 6089, 6608, 5052, 1180, 6397, 7740, 7989, 7591,  742, 7184,
       4553, 2641, 2795, 6143, 5985, 6299, 1103, 4603, 5881, 4873, 3078,
       2400, 8366, 5601, 1322, 7898, 3387, 1178, 4860, 2255, 4955, 3345,
       2279,  455, 6944, 6030, 7688, 4637, 5241, 8164, 4148, 5197, 1398,
       7171, 6153,  360, 3411, 1421, 6317, 7880, 2383, 3589, 8077, 7941,
       2038,  816, 4576, 1678, 2336, 4585, 6185, 3760, 4124, 5658, 2720,
       7373, 3025, 1043, 2150, 6521, 5132, 7543, 3080, 7221, 3785, 6155,
       6916, 4048, 5845,  125, 3796, 6478, 2292, 6417, 6395, 5616, 4959,
       5861, 2909, 1574, 6348, 4917, 5299, 3684, 1708, 4280, 8049, 6302,
       3238, 4509, 4388, 8135, 6550,  446, 3236, 1851, 3637, 5419, 6385,
       6821, 8129, 5896,  169, 1255, 2466, 4434, 3615,  884, 1654, 2070,
       5011, 6816, 5240, 4944, 2415, 5703, 2058, 5423, 6313, 5994, 4153,
       2775, 1389, 3607, 4871, 5773,  112, 7741, 7942, 7035, 6644,  212,
       7572, 3366, 7894, 3102, 5663, 5381, 3276, 1339, 2063,  870, 2067,
        226, 2001, 7857, 1818, 7660, 4763, 1470, 3893,  510, 3284,  271,
       4923, 5889, 6729, 2767, 4546, 2420,  453, 5394, 4114, 7520, 1538,
       7742, 3205, 8098, 7038, 1319, 7821, 3874, 5511,  178, 1486, 6879,
       4762, 4976,  833, 6462, 1366, 6177, 2639, 2295,  147,  177, 2608,
       1159, 5508, 8266,   63, 4009, 3137, 6214, 5604, 5340, 6826, 4441,
       3854, 6372, 3210,  103, 3465, 3355, 3552, 5862, 3474, 1021,   95,
       5268, 3340, 6481, 5927, 2658, 3826, 1510, 5448, 3094, 6873, 4407,
       1545, 5811,  173, 4845, 6055, 2271, 2843, 7382, 2393, 8071, 2549,
        950, 5893, 1495, 7696, 1073, 2355,  798,  626, 4919, 2162, 7060,
       1645, 6157, 8122, 6662, 3169, 4471, 8167, 4503, 7673, 3176, 5290,
       5683, 4474, 6240, 2040,  735, 7463, 4166, 5690,  794, 8339,   41,
       2654, 5498, 4062, 4689, 6318,  667, 5961, 7043, 4101, 1665,  746,
       2796, 3488, 4215, 1168,   17, 3545, 2774, 4248, 3616, 1946,  819,
       3648,   82, 5839,  775, 2960, 5909, 3010, 3956, 4628, 8045, 1506,
       2217, 7481, 4103, 5157, 1457, 7093, 7618, 1722, 2963, 3578, 1774,
       1011, 7358, 1136, 1064,  166, 6226, 2762,   79, 2167, 3412, 5715,
       2788, 8262, 7908, 5705,  863, 1783,  371, 1873, 2640, 5684, 5415,
       7513,  569, 7042,  934, 5224,  265, 2460, 6640, 2584, 3277,  851,
       6325, 4449, 7750, 7770, 3825,  683, 7640, 5633, 6596, 6315, 6941,
       2049, 4706, 2481, 4941, 3246,  284, 2625, 6815, 6360,  209, 8116,
       1813, 6010, 6546, 2980,  449, 1222, 4814, 4678, 5451, 5145, 8285,
       1635, 2721, 6502, 6113, 5305, 4068, 1084,  748,  701, 6135, 7873,
        770, 5069, 5330,  717, 4569, 5937, 6404, 7938, 7585, 7909, 4700,
       6548, 5821, 3499, 2675, 7041, 3714, 7299, 7605, 1744, 6371, 3805,
       6038, 3730, 2722, 2190, 6432, 3249, 7072, 3890, 2858, 7682, 5103,
         34, 4366, 4745, 2317,  823, 4616, 6671,  937, 8317, 8141,  939,
       2797, 4649, 5560, 5435, 4848, 2036, 2816, 3768, 3003, 4267, 2828,
       4601, 1704, 7045, 8117, 1687, 1508, 1435, 2199, 4974, 1600, 3136,
       7391, 1107, 3948, 2506, 7139, 1793, 3087, 2500, 2740, 6857, 5645,
       3375, 3852, 5520,   18, 2526, 2877, 8048, 5395, 1847, 1235, 2905,
       6896,  907, 4982,  997, 1399, 1020, 7226, 5593, 3735, 5207, 7778,
       4024, 7791, 7350, 2508,    2, 1854, 7799, 4329, 4754, 3656, 4396,
       6247, 5055, 7723, 7813, 3942, 4076, 5509, 8046, 2863, 7005, 3172,
        821, 6797, 7242, 5131, 1840, 2328, 7434,  474, 4903,  750, 8151,
       6956, 5447, 1984, 6838, 6669, 1691, 3469, 5119,  296, 3014, 3152,
       1204, 1674, 7055, 2444, 7936, 4106, 4358, 6105, 8358, 6694,   54,
       1242, 1057, 3602, 7884, 1639, 4711, 1521, 3957,  942,  951, 1496,
       3485, 2034, 6154, 1338, 5922, 7917, 7644, 7552, 2455, 5065, 2024,
       7057, 5309, 7904, 5384, 4461, 7551, 5546, 6848, 4686, 7282, 7468,
        920, 1451, 6311, 8345, 8105, 3445, 7311, 3446, 4802, 6868, 7815,
       6244, 2421, 4654, 3519, 1653, 1943, 5853, 7801, 8022, 5837, 4781,
       4977])

# %%
train_df = df.drop(df.index[test_idx])
test_df  = df.iloc[test_idx,:]

# %%
adj_train = create_adj_matrix(train_df)
adj_test  = create_adj_matrix(test_df)

# %%
plt.figure(figsize=(12,12))
plt.subplot(1,2,1)
plt.imshow(adj_train)
plt.title("Training One-Sided Decision Matrix")
plt.xlabel("pid")
plt.ylabel("iid")

plt.subplot(1,2,2)
plt.imshow(adj_test)
plt.title("Testing One-Sided Decision Matrix")
plt.xlabel("pid")
plt.ylabel("iid")
plt.show()

# %% [markdown]
# # Baseline Models

# %% [markdown]
# ## Predict Average

# %%
avg_dec = np.mean(train_df['dec'])
print("Train Rate of Acceptance:", round(avg_dec,2))
print("Most Likely Decision:", 0)
# Out:
# Train Rate of Acceptance: 0.42
# Most Likely Decision: 0

# %%
print("Test Accuracy Rate:", round(np.mean(test_df['dec'] == 0),2))
# Out:
# Test Accuracy Rate: 0.59

# %% [markdown]
# ## Predict Average for Gender

# %%
avg_dec_m = np.mean(train_df.loc[train_df['gender'] == 1, 'dec'])
avg_dec_f = np.mean(train_df.loc[train_df['gender'] == 0, 'dec'])

print("Male Train Rate of Acceptance:", round(avg_dec_m,2))
print("Female Train Rate of Acceptance:", round(avg_dec_f,2))
print("Most Likely Decision for both Genders:", 0)
# Out:
# Male Train Rate of Acceptance: 0.48
# Female Train Rate of Acceptance: 0.36
# Most Likely Decision for both Genders: 0

# %%
print("Test Accuracy Rate:", round(np.mean(test_df['dec'] == 0),2))
# Out:
# Test Accuracy Rate: 0.59

# %% [markdown]
# ## Cosine Similarity

# %%
# replace 0's with -1's for cosine similairty computations
adj_train_cos = adj_train.copy()
adj_train_cos[adj_train_cos == 0] = -1

adj_test_cos = adj_test.copy()
adj_test_cos[adj_test_cos == 0] = -1

# %%
# compute sigmoid function value
def sigmoid(x):
    return 1 / (1 + np.exp(-1 * x))

# %%
# compute cosine similarity between two users
def cosine_similarity(p1, p2):
    numerator = 0
    sum_p1 = 0
    sum_p2 = 0

    for i in range(n_ppl):
        if (~np.isnan(p1[i]) and ~np.isnan(p2[i])):
            numerator += p1[i] * p2[i]

            sum_p1 += p1[i]**2
            sum_p2 += p2[i]**2

    denominator = np.sqrt(sum_p1) * np.sqrt(sum_p2)  
    return numerator / denominator

# %%
# compute cosine similarities between user and all other users
def compute_cosine_similarities(user):
    similarities = np.zeros(n_ppl)
    similarities.fill(np.nan)
    
    for i in range(n_ppl):
        similarities[i] = cosine_similarity(user, adj_train_cos[i,:])
    
    return similarities

# %%
linear_values = np.zeros(len(train_df))

for i in range(len(test_df)):
    test_iid_idx = int(test_df['iid'].iloc[i] - 1)
    test_pid_idx = int(test_df['pid'].iloc[i] - 1)
    
    user = adj_train_cos[test_iid_idx,:]
    similarities = compute_cosine_similarities(user)
    
    decisions = adj_train_cos[~np.isnan(similarities), test_pid_idx]
    weights = similarities[~np.isnan(similarities)]
    
    linear_values[i] = np.nansum(decisions * weights)
    
    if (i % 50 == 0):
        print(i)
        
pred_prob = sigmoid(linear_values)
pred = np.round(pred_prob)
# Out:
# /Users/aarontrefler_temp2/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:15: RuntimeWarning: invalid value encountered in double_scalars
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-266-dbbee516f0d8> in <module>()
#      16         print(i)
#      17
# ---> 18 pred_prob = sigmoid(linear_values)
#      19 pred = np.round(pred_prob)
#
# <ipython-input-253-d1269f52fd20> in sigmoid(x)
#       1 def sigmoid(x):
# ----> 2     return 1 / (1 + math.exp(-x))
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
np.exp(linear_values)
# Out:
# array([  3.42181183e-02,   7.75498382e-04,   8.56793999e-02, ...,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00])

# %% [markdown]
# # Matrix Factorization

# %%
R = adj_train
N = len(R)
M = len(R[0])
K = 2

P = np.random.rand(N,K)
Q = np.random.rand(M,K)

# %%
# warm start initialization
P = np.loadtxt("../../models/mf/P.txt", delimiter=',')
Q = np.loadtxt("../../models/mf/Q.txt", delimiter=',')

# %%
nP, nQ = matrix_factorization(R, P, Q, K, verbose=0)

# %%
pred = np.round(np.dot(P,Q.T)).astype(int)

# %%
def mf_accuracy(adj_matrix, pred_matrix):
    n_correct = 0
    n_total = 0

    for i in range(n_ppl):
        for j in range(n_ppl):
            if ~np.isnan(adj_matrix[i][j]):          
                if (adj_matrix[i][j] == pred_matrix[i][j]):
                    n_correct +=1
                n_total +=1
    return n_correct / n_total

# %%
mf_accuracy(adj_train, pred)
# Out:
# 0.8722613198778383

# %%
mf_accuracy(adj_test, pred)
# Out:
# 0.7084826762246117
